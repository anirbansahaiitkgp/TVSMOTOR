# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical
import keras
import tensorflow

# Load your dataset
df = pd.read_csv("../DataSet/Commands_Classification_Dataset4.csv",encoding="latin1")  # Update with your dataset filename

# %%
df
# Out:
#         Class    Subclass SubclassCategory  \
# 0        Bike        Edge     Battery/Fuel
# 1        Bike        Edge     Battery/Fuel
# 2        Bike        Edge     Battery/Fuel
# 3        Bike        Edge     Battery/Fuel
# 4        Bike        Edge     Battery/Fuel
# ...       ...         ...              ...
# 2979  NonBike  Not needed               NC
# 2980  NonBike  Not needed               NC
# 2981  NonBike  Not needed               NC
# 2982  NonBike  Not needed               NC
# 2983  NonBike  Not needed               NC
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 2979                           Perform my pets marriage
# 2980                           Perform my dogs marriage
# 2981                               check blood pressure
# 2982                            check balloon pressure
# 2983                                     check my books
#
#                        Response  Label
# 0          Updating please wait      1
# 1          Updating please wait      1
# 2          Updating please wait      1
# 3          Updating please wait      1
# 4          Updating please wait      1
# ...                         ...    ...
# 2979  It is a  non bike command      0
# 2980  It is a  non bike command      0
# 2981  It is a  non bike command      0
# 2982  It is a  non bike command      0
# 2983  It is a  non bike command      0
#
# [2984 rows x 6 columns]

# %%
df['Subclass'].unique()
# Out:
# array(['Edge', 'Not needed', 'Cloud', 'Update', 'Miscellaneous'],
#       dtype=object)

# %%
new_df = df[df['Subclass'] != 'Not needed'].reset_index(drop=True)
new_df
# Out:
#      Class       Subclass SubclassCategory  \
# 0     Bike           Edge     Battery/Fuel
# 1     Bike           Edge     Battery/Fuel
# 2     Bike           Edge     Battery/Fuel
# 3     Bike           Edge     Battery/Fuel
# 4     Bike           Edge     Battery/Fuel
# ...    ...            ...              ...
# 1309  Bike  Miscellaneous        Temporary
# 1310  Bike  Miscellaneous        Temporary
# 1311  Bike  Miscellaneous        Temporary
# 1312  Bike  Miscellaneous        Temporary
# 1313  Bike  Miscellaneous        Temporary
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1309      Perform a bike suspension linkage lubrication
# 1310          Activate bike's adaptive throttle control
# 1311  Check for loose bolts in the bike's rear wheel...
# 1312             Perform a bike clutch cable inspection
# 1313  Activate bike's cruise control with speed limiter
#
#                                                Response  Label
# 0                                  Updating please wait      1
# 1                                  Updating please wait      1
# 2                                  Updating please wait      1
# 3                                  Updating please wait      1
# 4                                  Updating please wait      1
# ...                                                 ...    ...
# 1309  Regularly lubricate the suspension linkage for...      1
# 1310  Utilize adaptive throttle control for personal...      1
# 1311  Inspect and tighten any loose bolts in the rea...      1
# 1312  Inspect the clutch cable for signs of wear and...      1
# 1313  Utilize cruise control with speed limiter for ...      1
#
# [1314 rows x 6 columns]

# %%
new_df['Subclass'].unique()
# Out:
# array(['Edge', 'Cloud', 'Update', 'Miscellaneous'], dtype=object)

# %%
X=new_df['Commands']
X
# Out:
# 0                       What is my current battery level?
# 1            How much range do I have left on my battery?
# 2          When was the last time my battery was charged?
# 3             How long until my battery is fully charged?
# 4       How long should I charge my vehicle for a suff...
#                               ...
# 1309        Perform a bike suspension linkage lubrication
# 1310            Activate bike's adaptive throttle control
# 1311    Check for loose bolts in the bike's rear wheel...
# 1312               Perform a bike clutch cable inspection
# 1313    Activate bike's cruise control with speed limiter
# Name: Commands, Length: 1314, dtype: object

# %%
# Automatically convert categorical values to labels
new_df['Subclass_Label'], _ = pd.factorize(new_df['Subclass'])
new_df['Subclass_Label']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1309    3
# 1310    3
# 1311    3
# 1312    3
# 1313    3
# Name: Subclass_Label, Length: 1314, dtype: int64

# %%
new_df
# Out:
#      Class       Subclass SubclassCategory  \
# 0     Bike           Edge     Battery/Fuel
# 1     Bike           Edge     Battery/Fuel
# 2     Bike           Edge     Battery/Fuel
# 3     Bike           Edge     Battery/Fuel
# 4     Bike           Edge     Battery/Fuel
# ...    ...            ...              ...
# 1309  Bike  Miscellaneous        Temporary
# 1310  Bike  Miscellaneous        Temporary
# 1311  Bike  Miscellaneous        Temporary
# 1312  Bike  Miscellaneous        Temporary
# 1313  Bike  Miscellaneous        Temporary
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1309      Perform a bike suspension linkage lubrication
# 1310          Activate bike's adaptive throttle control
# 1311  Check for loose bolts in the bike's rear wheel...
# 1312             Perform a bike clutch cable inspection
# 1313  Activate bike's cruise control with speed limiter
#
#                                                Response  Label  Subclass_Label
# 0                                  Updating please wait      1               0
# 1                                  Updating please wait      1               0
# 2                                  Updating please wait      1               0
# 3                                  Updating please wait      1               0
# 4                                  Updating please wait      1               0
# ...                                                 ...    ...             ...
# 1309  Regularly lubricate the suspension linkage for...      1               3
# 1310  Utilize adaptive throttle control for personal...      1               3
# 1311  Inspect and tighten any loose bolts in the rea...      1               3
# 1312  Inspect the clutch cable for signs of wear and...      1               3
# 1313  Utilize cruise control with speed limiter for ...      1               3
#
# [1314 rows x 7 columns]

# %%
y=new_df['Subclass_Label']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1309    3
# 1310    3
# 1311    3
# 1312    3
# 1313    3
# Name: Subclass_Label, Length: 1314, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
# Assuming 'Class' column contains the commands and 'Label' column contains the labels for multiclass classification
# Assuming df is your DataFrame
# X = df['Commands']  # Input features
# y = df['Label']      # Target variable

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_sequences = tokenizer.texts_to_sequences(X)

# Padding sequences to make them of equal length
max_sequence_length = max([len(seq) for seq in X_sequences])
X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')

# Convert labels to one-hot encoding
y_encoded = to_categorical(y)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)
#, stratify=y_encoded

# Define the RNN model for multiclass classification
num_classes = len(np.unique(y))  # Number of unique classes
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_sequence_length))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dense(num_classes, activation='softmax'))  # Use softmax activation for multiclass classification

# Compile the model with categorical cross-entropy loss
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.3587 - loss: 1.3242 - val_accuracy: 0.3042 - val_loss: 1.3076
# Epoch 2/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3173 - loss: 1.3014 - val_accuracy: 0.5703 - val_loss: 0.9510
# Epoch 3/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.5573 - loss: 0.9019 - val_accuracy: 0.6692 - val_loss: 0.6974
# Epoch 4/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.6587 - loss: 0.6724 - val_accuracy: 0.7605 - val_loss: 0.6375
# Epoch 5/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8047 - loss: 0.4825 - val_accuracy: 0.7605 - val_loss: 0.5703
# Epoch 6/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8470 - loss: 0.3851 - val_accuracy: 0.8213 - val_loss: 0.5828
# Epoch 7/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.8712 - loss: 0.3736 - val_accuracy: 0.8479 - val_loss: 0.3933
# Epoch 8/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.9103 - loss: 0.2349 - val_accuracy: 0.8365 - val_loss: 0.3862
# Epoch 9/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9269 - loss: 0.1967 - val_accuracy: 0.8745 - val_loss: 0.3341
# Epoch 10/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9500 - loss: 0.1611 - val_accuracy: 0.8593 - val_loss: 0.5202
# Epoch 11/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9716 - loss: 0.1046 - val_accuracy: 0.8593 - val_loss: 0.4662
# Epoch 12/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9276 - loss: 0.2092 - val_accuracy: 0.8593 - val_loss: 0.5082
# Epoch 13/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9352 - loss: 0.1629 - val_accuracy: 0.8517 - val_loss: 0.4058
# Epoch 14/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9620 - loss: 0.1278 - val_accuracy: 0.8441 - val_loss: 0.4754
# Epoch 15/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9569 - loss: 0.1131 - val_accuracy: 0.8517 - val_loss: 0.4551
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8455 - loss: 0.4597
# Test Loss: 0.45510873198509216
# Test Accuracy: 0.8517110347747803

# %%
# Function to predict the class of a command
def predict_class(command):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
y_encoded[11]
print(y.count())
print(y.unique())
# Out:
# 1314
# [0 1 2 3]

# %%
tokenizer

# %%
import joblib
# Assuming model is your trained model object
joblib.dump(model, './RNN_save_model/LSTM/MAINMODEL/RNN_Multiclass_Subclass.joblib')
joblib.dump(tokenizer, './RNN_save_model/LSTM/MAINMODEL/tokenizer.joblib')
joblib.dump(max_sequence_length, './RNN_save_model/LSTM/MAINMODEL/max_sequence_length_mainModel.joblib')
# Out:
# ['./RNN_save_model/LSTM/MAINMODEL/max_sequence_length_mainModel.joblib']

# %%
# # Example usage:
# command_input = input("Enter a command: ")
# print(command_input)
# prediction = predict_class(command_input)
# if(prediction==0):
#     print("Edge :", prediction)
# elif(prediction==1):
#     print("Cloud :", prediction)
# elif(prediction==2):
#     print("Update :",prediction)
# elif(prediction==3):
#     print("Miscellaneous :",prediction)
# else:
#     print("Dont know")

# %%
# Load your dataset
df_test = pd.read_csv("../DataSet/Comparision_AvsS.csv",encoding="latin1")  # Update with your dataset filename

# %%
df_test['Command']
# Out:
# 0                               Please check for update
# 1                         Please show me current update
# 2                            please perform bike update
# 3                     please kindly perform bike update
# 4              will I reach hyderabad with current fuel
# 5                                      Check for update
# 6                                Show me current update
# 7                                   perform bike update
# 8                            kindly perform bike update
# 9     Kindly tell me  whether will I reach hyderabad...
# 10            Is current fuel enough to reach Hyderabad
# 11                       Are my tyres pressure balanced
# 12                 Show me the fastest route to kolkata
# 13                   Will it rain tomorrow in bangaluru
# 14                  What is the weather status in delhi
# 15                        Play my playlist form spotify
# 16                                            Go to goa
# 17                                     Please go to goa
# 18                                       Take me to goa
# 19                     What is my current battery level
# 20                          Check my current fuel level
# 21                         Do I need to change the tyre
# 22                      Check tyre pressure and balance
# 23                   Check if tyre pressure is balanced
# 24                          what is current temperature
# 25              turn off the left indicator of the bike
# 26              turn on the right indicator of the bike
# 27                Show me the fastest route from X to Y
# 28          Can you recommend a charging station nearby
# 29                  Will it rain heavily in Delhi today
# 30            What is the temperature outisde right now
# 31                  Did I receive messages on Instagram
# 32              Are there any missed calls or app alert
# 33                 Play my favourite songs form Spotify
# 34                   Can you play some background music
# 35               Terminate pending bike software update
# 36                    Cancel bike system update process
# 37                     Begin bike software system upate
# 38              Please begin bike software system upate
# 39    Please check for available system updates for ...
# 40                   Please verify pending bike updates
# Name: Command, dtype: object

# %%
results=[]
for cmds in df_test['Command']:
    prediction = predict_class(cmds)
    if(prediction==0):
        print("Edge :", prediction)
        results.append('EDGE')
    elif(prediction==1):
        print("Cloud :", prediction)
        results.append('CLOUD')
    elif(prediction==2):
        print("Update :",prediction)
        results.append('UPDATE')
    elif(prediction==3):
        print("Miscellaneous :",prediction)
        results.append('MISCELLANEOUS')
    else:
        print("Dont know")
        
print(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Update : 2
# ['UPDATE', 'CLOUD', 'UPDATE', 'UPDATE', 'CLOUD', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'CLOUD', 'EDGE', 'EDGE', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'EDGE', 'EDGE', 'EDGE', 'EDGE', 'EDGE', 'CLOUD', 'EDGE', 'EDGE', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE']

# %%
#results

# %%
# Convert list to DataFrame
df_testResult = pd.DataFrame(results, columns=['Test_Result'])
#df_testResult

# %%
dfconcat_testResult= pd.concat([df_test['Command'],df_test['SubClass'], df_testResult['Test_Result']], axis=1)

# Convert values in 'SubClass' column to uppercase
dfconcat_testResult['SubClass'] = dfconcat_testResult['SubClass'].str.upper()

# Create 'TrueFalse' column based on conditions
dfconcat_testResult['TrueFalse'] = dfconcat_testResult['SubClass'] == dfconcat_testResult['Test_Result'].str.upper()

dfconcat_testResult
# Out:
#                                               Command SubClass Test_Result  \
# 0                             Please check for update   UPDATE      UPDATE
# 1                       Please show me current update   UPDATE       CLOUD
# 2                          please perform bike update   UPDATE      UPDATE
# 3                   please kindly perform bike update   UPDATE      UPDATE
# 4            will I reach hyderabad with current fuel     EDGE       CLOUD
# 5                                    Check for update   UPDATE      UPDATE
# 6                              Show me current update   UPDATE      UPDATE
# 7                                 perform bike update   UPDATE      UPDATE
# 8                          kindly perform bike update   UPDATE      UPDATE
# 9   Kindly tell me  whether will I reach hyderabad...     EDGE       CLOUD
# 10          Is current fuel enough to reach Hyderabad     EDGE        EDGE
# 11                     Are my tyres pressure balanced     EDGE        EDGE
# 12               Show me the fastest route to kolkata    CLOUD       CLOUD
# 13                 Will it rain tomorrow in bangaluru    CLOUD       CLOUD
# 14                What is the weather status in delhi    CLOUD       CLOUD
# 15                      Play my playlist form spotify    CLOUD       CLOUD
# 16                                          Go to goa    CLOUD       CLOUD
# 17                                   Please go to goa    CLOUD       CLOUD
# 18                                     Take me to goa    CLOUD       CLOUD
# 19                   What is my current battery level     EDGE        EDGE
# 20                        Check my current fuel level     EDGE        EDGE
# 21                       Do I need to change the tyre     EDGE        EDGE
# 22                    Check tyre pressure and balance     EDGE        EDGE
# 23                 Check if tyre pressure is balanced     EDGE        EDGE
# 24                        what is current temperature    CLOUD       CLOUD
# 25            turn off the left indicator of the bike     EDGE        EDGE
# 26            turn on the right indicator of the bike     EDGE        EDGE
# 27              Show me the fastest route from X to Y    CLOUD       CLOUD
# 28        Can you recommend a charging station nearby    CLOUD       CLOUD
# 29                Will it rain heavily in Delhi today    CLOUD       CLOUD
# 30          What is the temperature outisde right now    CLOUD       CLOUD
# 31                Did I receive messages on Instagram    CLOUD       CLOUD
# 32            Are there any missed calls or app alert    CLOUD       CLOUD
# 33               Play my favourite songs form Spotify    CLOUD       CLOUD
# 34                 Can you play some background music    CLOUD       CLOUD
# 35             Terminate pending bike software update   UPDATE      UPDATE
# 36                  Cancel bike system update process   UPDATE      UPDATE
# 37                   Begin bike software system upate   UPDATE      UPDATE
# 38            Please begin bike software system upate   UPDATE      UPDATE
# 39  Please check for available system updates for ...   UPDATE      UPDATE
# 40                 Please verify pending bike updates   UPDATE      UPDATE
#
#     TrueFalse
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True

# %%
#######################################################################################################################
############################################## Subclass Category ######################################################

# %%
df_edge = df[df['Subclass'] == 'Edge']
df_cloud = df[df['Subclass'] == 'Cloud']
df_update = df[df['Subclass'] == 'Update']
df_miscellaneous = df[df['Subclass'] == 'Miscellaneous']
df_notneeded = df[df['Subclass'] == 'Not needed']

df_edge.reset_index(drop=True, inplace=True)
df_cloud.reset_index(drop=True, inplace=True)
df_update.reset_index(drop=True, inplace=True)
df_miscellaneous.reset_index(drop=True, inplace=True)
df_notneeded.reset_index(drop=True, inplace=True)

# %%
df_edge
# Save DataFrame to a CSV file
#df_edge.to_csv("df_edge.csv", index=False)
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike     Edge     Battery/Fuel
# 1    Bike     Edge     Battery/Fuel
# 2    Bike     Edge     Battery/Fuel
# 3    Bike     Edge     Battery/Fuel
# 4    Bike     Edge     Battery/Fuel
# ..    ...      ...              ...
# 425  Bike     Edge            Basic
# 426  Bike     Edge            Basic
# 427  Bike     Edge            Basic
# 428  Bike     Edge     Battery/Fuel
# 429  Bike     Edge      Tires/Tyres
#
#                                               Commands  \
# 0                    What is my current battery level?
# 1         How much range do I have left on my battery?
# 2       When was the last time my battery was charged?
# 3          How long until my battery is fully charged?
# 4    How long should I charge my vehicle for a suff...
# ..                                                 ...
# 425                                       Start Engine
# 426                                        Stop Engine
# 427                          Activate bike's rain mode
# 428              Perform a bike fuel injector cleaning
# 429   Activate bike's tire/tyre temperature monitoring
#
#                                               Response  Label
# 0                                 Updating please wait      1
# 1                                 Updating please wait      1
# 2                                 Updating please wait      1
# 3                                 Updating please wait      1
# 4                                 Updating please wait      1
# ..                                                 ...    ...
# 425   Processing your fuel related command please wait      1
# 426   Processing your fuel related command please wait      1
# 427  Utilize rain mode for safer riding in wet cond...      1
# 428  Clean fuel injectors for improved fuel atomiza...      1
# 429  Utilize tire/tyre temperature monitoring for o...      1
#
# [430 rows x 6 columns]

# %%
df_cloud
# Save DataFrame to a CSV file
#df_cloud.to_csv("df_cloud.csv", index=False)
# Out:
#     Class Subclass SubclassCategory                               Commands  \
# 0    Bike    Cloud      Songs/media                    Play "XYZ" by "ABC"
# 1    Bike    Cloud      Songs/media                 Play my favorite song.
# 2    Bike    Cloud      Songs/media                   Start playing music.
# 3    Bike    Cloud      Songs/media                   Shuffle my playlist.
# 4    Bike    Cloud      Songs/media                 Play the latest track.
# ..    ...      ...              ...                                    ...
# 443  Bike    Cloud     Traffic/Maps  Navigate to hyderbad/kolkata/banglore
# 444  Bike    Cloud          Weather                 Check weather forecast
# 445  Bike    Cloud      Songs/media                             Play music
# 446  Bike    Cloud     Traffic/Maps                    Take a scenic route
# 447  Bike    Cloud     Traffic/Maps              Check for traffic updates
#
#                                               Response  Label
# 0         Please wait, your request is been processed.      1
# 1         Please wait, your request is been processed.      1
# 2         Please wait, your request is been processed.      1
# 3         Please wait, your request is been processed.      1
# 4         Please wait, your request is been processed.      1
# ..                                                 ...    ...
# 443  You receive turn-by-turn directions to [destin...      1
# 444                 The weather forecast is [weather].      1
# 445                Your favorite music starts playing.      1
# 446            The navigation suggests a scenic route.      1
# 447        There are no traffic updates at the moment.      1
#
# [448 rows x 6 columns]

# %%
df_update
# Save DataFrame to a CSV file
#df_update.to_csv("df_update.csv", index=False)
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike   Update           Cancel
# 1    Bike   Update           Cancel
# 2    Bike   Update           Cancel
# 3    Bike   Update           Cancel
# 4    Bike   Update           Cancel
# ..    ...      ...              ...
# 307  Bike   Update            Check
# 308  Bike   Update            Check
# 309  Bike   Update            Check
# 310  Bike   Update            Check
# 311  Bike   Update            Check
#
#                                               Commands  \
# 0                   Abort pending bike firmware update
# 1                     Abort pending bike system update
# 2                       Abort software update for bike
# 3                          Cancel bike firmware update
# 4                  Cancel bike software update process
# ..                                                 ...
# 307  Look into firmware update schedules for my ele...
# 308  Verify the compatibility of the latest softwar...
# 309  Find out if there are any performance improvem...
# 310  Check if there are any security patches includ...
# 311  Inquire about the process for manually trigger...
#
#                       Response  Label
# 0         Aborting please wait      1
# 1         Aborting please wait      1
# 2         Aborting please wait      1
# 3         Aborting please wait      1
# 4         Aborting please wait      1
# ..                         ...    ...
# 307  Checking for your request      1
# 308  Checking for your request      1
# 309  Checking for your request      1
# 310  Checking for your request      1
# 311  Checking for your request      1
#
# [312 rows x 6 columns]

# %%
df_miscellaneous
# Save DataFrame to a CSV file
#df_miscellaneous.to_csv("df_miscellaneous.csv", index=False)
# Out:
#     Class       Subclass SubclassCategory  \
# 0    Bike  Miscellaneous        Temporary
# 1    Bike  Miscellaneous        Temporary
# 2    Bike  Miscellaneous        Temporary
# 3    Bike  Miscellaneous        Temporary
# 4    Bike  Miscellaneous        Temporary
# ..    ...            ...              ...
# 119  Bike  Miscellaneous        Temporary
# 120  Bike  Miscellaneous        Temporary
# 121  Bike  Miscellaneous        Temporary
# 122  Bike  Miscellaneous        Temporary
# 123  Bike  Miscellaneous        Temporary
#
#                                               Commands  \
# 0            Perform a bike valve clearance adjustment
# 1                       Activate bike's wind deflector
# 2      Check for loose bolts in the bike's chain guard
# 3               Perform a bike brake fluid replacement
# 4                Activate bike's emergency stop signal
# ..                                                 ...
# 119      Perform a bike suspension linkage lubrication
# 120          Activate bike's adaptive throttle control
# 121  Check for loose bolts in the bike's rear wheel...
# 122             Perform a bike clutch cable inspection
# 123  Activate bike's cruise control with speed limiter
#
#                                               Response  Label
# 0    Adjust valve clearance for proper engine funct...      1
# 1    Utilize the wind deflector for reduced wind tu...      1
# 2    Inspect and tighten any loose bolts in the cha...      1
# 3    Regularly replace brake fluid for optimal brak...      1
# 4    Utilize the emergency stop signal for enhanced...      1
# ..                                                 ...    ...
# 119  Regularly lubricate the suspension linkage for...      1
# 120  Utilize adaptive throttle control for personal...      1
# 121  Inspect and tighten any loose bolts in the rea...      1
# 122  Inspect the clutch cable for signs of wear and...      1
# 123  Utilize cruise control with speed limiter for ...      1
#
# [124 rows x 6 columns]

# %%
df_notneeded
# Save DataFrame to a CSV file
#df_notneeded.to_csv("df_notneeded.csv", index=False)
# Out:
#         Class    Subclass SubclassCategory                  Commands  \
# 0        Bike  Not needed        Greetings                   Hi TVS!
# 1        Bike  Not needed        Greetings           Hello, Vehicle!
# 2        Bike  Not needed        Greetings             Good morning!
# 3        Bike  Not needed        Greetings           Good afternoon!
# 4        Bike  Not needed        Greetings             Good evening!
# ...       ...         ...              ...                       ...
# 1665  NonBike  Not needed               NC  Perform my pets marriage
# 1666  NonBike  Not needed               NC  Perform my dogs marriage
# 1667  NonBike  Not needed               NC      check blood pressure
# 1668  NonBike  Not needed               NC   check balloon pressure
# 1669  NonBike  Not needed               NC            check my books
#
#                        Response  Label
# 0                            Hi      1
# 1                         Hello      1
# 2                  Good morning      1
# 3                Good afternoon      1
# 4                  Good evening      1
# ...                         ...    ...
# 1665  It is a  non bike command      0
# 1666  It is a  non bike command      0
# 1667  It is a  non bike command      0
# 1668  It is a  non bike command      0
# 1669  It is a  non bike command      0
#
# [1670 rows x 6 columns]

# %%
# Function to predict the class of a command
def predict_class(command,tokenizer,model,max_sequence_length):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
def train_model_subClassCategory(df,filename,subclassCat):
    
    X=df['Commands']
    #print(X)
    df=df.copy()
    # Automatically convert categorical values to labels
    df['Subclass_Label_Category'], _ = pd.factorize(df['SubclassCategory'])
    #print(df['Subclass_Label_Category'].unique())
    
    # Save DataFrame to a CSV file
    df.to_csv(filename, index=False)

    y=df['Subclass_Label_Category']
    #print(y.unique())
    # Tokenize the text data
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(X)
    X_sequences = tokenizer.texts_to_sequences(X)
    
    #print('print 1')
    # Padding sequences to make them of equal length
    max_sequence_length = max([len(seq) for seq in X_sequences])
    X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')

    #print('print 2')
    # Convert labels to one-hot encoding
    y_encoded = to_categorical(y)
    #print(y)
    print(np.unique(y))
    #print('print 3')
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)
    #,stratify=y_encoded

    #print('print 4')
    # Define the RNN model for multiclass classification
    num_classes = len(np.unique(y))  # Number of unique classes
    model = Sequential()
    model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_sequence_length))

    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax activation for multiclass classification

    # Compile the model with categorical cross-entropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))
    
    # Assuming model is your trained model object
    joblib.dump(model, './RNN_save_model/LSTM/'+subclassCat+'/RNN_Multiclass_SubclassCategory.joblib')
    joblib.dump(tokenizer, './RNN_save_model/LSTM/'+subclassCat+'/tokenizer.joblib')
    joblib.dump(max_sequence_length, './RNN_save_model/LSTM/'+subclassCat+'/max_sequence_length.joblib')
    

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print("Test Loss:", loss)
    print("Test Accuracy:", accuracy)
    
    return model,tokenizer, max_sequence_length

# %%
######################################################EDGE########################################################
filename="df_edge.csv"
subclasscat="EDGE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_edge,filename,subclasscat)
# Out:
# [0 1 2]
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.3540 - loss: 1.0914 - val_accuracy: 0.3721 - val_loss: 1.0627
# Epoch 2/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4857 - loss: 0.9955 - val_accuracy: 0.7209 - val_loss: 0.7495
# Epoch 3/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8672 - loss: 0.5734 - val_accuracy: 0.9186 - val_loss: 0.2999
# Epoch 4/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9468 - loss: 0.2485 - val_accuracy: 0.9535 - val_loss: 0.2304
# Epoch 5/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9668 - loss: 0.1395 - val_accuracy: 0.8372 - val_loss: 0.5247
# Epoch 6/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9460 - loss: 0.1939 - val_accuracy: 0.9186 - val_loss: 0.2837
# Epoch 7/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9664 - loss: 0.1566 - val_accuracy: 0.9070 - val_loss: 0.2745
# Epoch 8/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9673 - loss: 0.1145 - val_accuracy: 0.9302 - val_loss: 0.2378
# Epoch 9/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9630 - loss: 0.1505 - val_accuracy: 0.9419 - val_loss: 0.1986
# Epoch 10/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9584 - loss: 0.1637 - val_accuracy: 0.9651 - val_loss: 0.1734
# Epoch 11/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9737 - loss: 0.1139 - val_accuracy: 0.9767 - val_loss: 0.1438
# Epoch 12/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9673 - loss: 0.1276 - val_accuracy: 0.9767 - val_loss: 0.1444
# Epoch 13/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9667 - loss: 0.1169 - val_accuracy: 0.9419 - val_loss: 0.2266
# Epoch 14/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9756 - loss: 0.0910 - val_accuracy: 0.9419 - val_loss: 0.2207
# Epoch 15/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9734 - loss: 0.1107 - val_accuracy: 0.9419 - val_loss: 0.2248
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9319 - loss: 0.2704
# Test Loss: 0.224812313914299
# Test Accuracy: 0.9418604373931885

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Edge -> Battery Fuel:", prediction)
elif(prediction==1):
    print("Edge -> Tires:", prediction)
elif(prediction==2):
    print("Edge -> Basic :",prediction)
else:
    print("Dont know")
# Out:
# check for tyre pressure please
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# Edge -> Tires: 1

# %%
########################################################CLOUD###############################################
filename="df_cloud.csv"
subclasscat="CLOUD"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_cloud,filename,subclasscat)
# Out:
# [0 1 2 3]
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.2977 - loss: 1.3860 - val_accuracy: 0.3333 - val_loss: 1.3965
# Epoch 2/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.3162 - loss: 1.3688 - val_accuracy: 0.5444 - val_loss: 1.2766
# Epoch 3/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.5326 - loss: 1.1614 - val_accuracy: 0.4778 - val_loss: 1.0800
# Epoch 4/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.5579 - loss: 0.9193 - val_accuracy: 0.6889 - val_loss: 0.7910
# Epoch 5/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6941 - loss: 0.7067 - val_accuracy: 0.7111 - val_loss: 0.6971
# Epoch 6/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7630 - loss: 0.5453 - val_accuracy: 0.7889 - val_loss: 0.6405
# Epoch 7/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8228 - loss: 0.4803 - val_accuracy: 0.7778 - val_loss: 0.6643
# Epoch 8/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8618 - loss: 0.4219 - val_accuracy: 0.7889 - val_loss: 0.6235
# Epoch 9/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9161 - loss: 0.3233 - val_accuracy: 0.8556 - val_loss: 0.4564
# Epoch 10/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9656 - loss: 0.1887 - val_accuracy: 0.8778 - val_loss: 0.4203
# Epoch 11/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9913 - loss: 0.1042 - val_accuracy: 0.8667 - val_loss: 0.3643
# Epoch 12/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9904 - loss: 0.0754 - val_accuracy: 0.9111 - val_loss: 0.3016
# Epoch 13/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9927 - loss: 0.0529 - val_accuracy: 0.8778 - val_loss: 0.4177
# Epoch 14/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9982 - loss: 0.0361 - val_accuracy: 0.9000 - val_loss: 0.3700
# Epoch 15/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9950 - loss: 0.0423 - val_accuracy: 0.8667 - val_loss: 0.4379
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8943 - loss: 0.3417
# Test Loss: 0.43790435791015625
# Test Accuracy: 0.8666666746139526

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Cloud -> Song Media:", prediction)
elif(prediction==1):
    print("Cloud -> News Notification:", prediction)
elif(prediction==2):
    print("Cloud -> Weather :",prediction)
elif(prediction==3):
    print("Cloud -> Traffic Maps :",prediction)
else:
    print("Dont know")
# Out:
# enroute me to goa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Cloud -> News Notification: 1

# %%
###########################################Update#################################################
filename="df_update.csv"
subclasscat="UPDATE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_update,filename,subclasscat)
# Out:
# [0 1 2]
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.2403 - loss: 1.0954 - val_accuracy: 0.6032 - val_loss: 1.0582
# Epoch 2/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5579 - loss: 1.0295 - val_accuracy: 0.6825 - val_loss: 0.8123
# Epoch 3/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7091 - loss: 0.7486 - val_accuracy: 0.7460 - val_loss: 0.5814
# Epoch 4/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7203 - loss: 0.6028 - val_accuracy: 0.6984 - val_loss: 0.5243
# Epoch 5/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8089 - loss: 0.4284 - val_accuracy: 0.9683 - val_loss: 0.2530
# Epoch 6/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9457 - loss: 0.2530 - val_accuracy: 0.9683 - val_loss: 0.1707
# Epoch 7/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9506 - loss: 0.1575 - val_accuracy: 0.9841 - val_loss: 0.0801
# Epoch 8/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9825 - loss: 0.1109 - val_accuracy: 1.0000 - val_loss: 0.0418
# Epoch 9/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9883 - loss: 0.0687 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 10/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9984 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0260
# Epoch 11/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9836 - loss: 0.0718 - val_accuracy: 1.0000 - val_loss: 0.0217
# Epoch 12/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9927 - loss: 0.0526 - val_accuracy: 1.0000 - val_loss: 0.0180
# Epoch 13/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0161
# Epoch 14/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 15/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0124
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0122
# Test Loss: 0.012433350086212158
# Test Accuracy: 1.0

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Update -> Cancel:", prediction)
elif(prediction==1):
    print("Update -> Perform:", prediction)
elif(prediction==2):
    print("Update -> Check:",prediction)
else:
    print("Dont know")
# Out:
# abort software update
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Update -> Cancel: 0
